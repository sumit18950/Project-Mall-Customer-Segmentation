# %% [markdown]
# ## Data Collection

# %% [markdown]
# •	Importing the dataset
#
# •	Brief overview of the dataset

# %%
import pandas as pd

# Load the dataset
file_path = 'Mall_Customers.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %% [markdown]
# # Data Cleaning
#
# •	Handling missing values
#
# •	Data transformation
#
# •	Handling outliers

# %%
count=data.isnull().sum()
count
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
mean_age=data['Age'].mean()

# %%
data["Age"].fillna(mean_age,inplace=True)

# %%
data.head(10)
# Out:
#    CustomerID   Genre        Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.000000                15.0                    39.0
# 1           2    Male  21.000000                15.0                    81.0
# 2           3  Female  38.704663                16.0                     6.0
# 3           4  Female  23.000000                16.0                    77.0
# 4           5  Female  31.000000                 NaN                    40.0
# 5           6  Female  22.000000                 NaN                    76.0
# 6           7  Female  35.000000                18.0                     6.0
# 7           8  Female  23.000000                18.0                    94.0
# 8           9    Male  64.000000                19.0                     NaN
# 9          10  Female  30.000000                19.0                    72.0

# %%
# Renaming columns for better readability
data.columns = ["CustomerID", "Gender", "Age", "AnnualIncome", "SpendingScore"]

# %%
data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
mode_gender=data['Gender'].mode()[0]
type(mode_gender)
mode_gender
# Out:
# 'Female'

# %%
data.dropna(inplace=True)

# %%
data["Gender"].fillna(mode_gender,inplace=True)

# %%
data.head(20)
# Out:
#     CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male   19                  15                      39
# 1            2    Male   21                  15                      81
# 2            3  Female   20                  16                       6
# 3            4  Female   23                  16                      77
# 4            5  Female   31                  17                      40
# 5            6  Female   22                  17                      76
# 6            7  Female   35                  18                       6
# 7            8  Female   23                  18                      94
# 8            9    Male   64                  19                       3
# 9           10  Female   30                  19                      72
# 10          11    Male   67                  19                      14
# 11          12  Female   35                  19                      99
# 12          13  Female   58                  20                      15
# 13          14  Female   24                  20                      77
# 14          15    Male   37                  20                      13
# 15          16    Male   22                  20                      79
# 16          17  Female   35                  21                      35
# 17          18    Male   20                  21                      66
# 18          19    Male   52                  23                      29
# 19          20  Female   35                  23                      98

# %%
count=data.isnull().sum()
count
# Out:
# CustomerID       0
# Gender           0
# Age              0
# AnnualIncome     0
# SpendingScore    0
# dtype: int64

# %%
# Data transformation (e.g., encoding categorical variables)
data['Gender'] = data['Gender'].map({'Male': 0, 'Female': 1})

# %%
count=data.isnull().sum()
count
# Out:
# CustomerID       0
# Gender           0
# Age              0
# AnnualIncome     8
# SpendingScore    3
# dtype: int64

# %%
data
# Out:
#      CustomerID  Gender        Age  AnnualIncome  SpendingScore
# 0             1       0  19.000000          15.0           39.0
# 1             2       0  21.000000          15.0           81.0
# 2             3       1  38.704663          16.0            6.0
# 3             4       1  23.000000          16.0           77.0
# 4             5       1  31.000000           NaN           40.0
# ..          ...     ...        ...           ...            ...
# 195         196       1  35.000000         120.0           79.0
# 196         197       1  45.000000         126.0           28.0
# 197         198       0  32.000000         126.0           74.0
# 198         199       0  32.000000         137.0           18.0
# 199         200       0  30.000000         137.0           83.0
#
# [200 rows x 5 columns]

# %%
#data['Gender'] = data['Gender'].astype(int)

# %% [markdown]
# # Exploratory Data Analysis (EDA):
#
# •	Descriptive statistics
#
# •	Visualizing distributions and relationships using Matplotlib
#
# •	Insights from visualizations

# %%
data.describe()
# Out:
#        CustomerID         Age  AnnualIncome  SpendingScore
# count  200.000000  200.000000    200.000000     200.000000
# mean   100.500000   38.850000     60.560000      50.200000
# std     57.879185   13.969007     26.264721      25.823522
# min      1.000000   18.000000     15.000000       1.000000
# 25%     50.750000   28.750000     41.500000      34.750000
# 50%    100.500000   36.000000     61.500000      50.000000
# 75%    150.250000   49.000000     78.000000      73.000000
# max    200.000000   70.000000    137.000000      99.000000

# %% [markdown]
# # Visualization with Matplotlib:
# •	Visualizing clusters
#
# •	Detailed analysis using various plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#histplot-Age,Annual income,Spending score
# Visualizing distributions
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data['AnnualIncome'], bins=30, kde=True)
plt.title('Annual Income Distribution')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data['SpendingScore'], bins=30, kde=True)
plt.title('Spending Score Distribution')
plt.show()

# Visualizing relationships
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='AnnualIncome', y='SpendingScore', hue='Gender')
plt.title('Income vs Spending Score')
plt.show()

# %% [markdown]
# # Customer Segmentation:
# •	Feature selection
#
# •	Using K-Means clustering for segmentation
#
# •	Evaluating cluster quality

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Feature selection
features = data[['Age', 'AnnualIncome', 'SpendingScore']]

# Standardizing the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Applying K-Means clustering
kmeans = KMeans(n_clusters=5, random_state=42)
data['Cluster'] = kmeans.fit_predict(scaled_features)

# Evaluating cluster quality
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='AnnualIncome', y='SpendingScore', hue='Cluster', palette='viridis')
plt.title('Customer Segments')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # Visualization with Power BI
#
# here am attaching PowerBi link:
#
# https://app.powerbi.com/view?r=eyJrIjoiZWJlMTE1NjEtYTQyZC00MjNmLWIwZjktZjIzOTg1OGM5ZjNiIiwidCI6ImUxNGU3M2ViLTUyNTEtNDM4OC04ZDY3LThmOWYyZTJkNWE0NiIsImMiOjEwfQ%3D%3D
